# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.svm import LinearSVR, SVC, SVR
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, VotingRegressor
import xgboost

# %%
df = pd.read_csv("./data/Data_CHF_Zhao_2020_ATE.csv")
df.drop(columns="id", inplace=True)

# %%
df.describe()
# Out:
#        pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]     D_e [mm]  \
# count     1865.000000          1865.000000  1865.000000  1865.000000
# mean        10.010949          2862.647721     0.016179     9.417212
# std          4.282715          1656.412247     0.117575     6.333807
# min          0.100000             0.000000    -0.866700     1.000000
# 25%          6.890000          1519.000000    -0.048300     5.600000
# 50%         10.340000          2590.000000     0.024400     8.500000
# 75%         13.790000          3933.000000     0.100600    11.100000
# max         20.680000          7975.000000     0.232000    37.500000
#
#           D_h [mm]  length [mm]  chf_exp [MW/m2]
# count  1865.000000  1865.000000      1865.000000
# mean     16.167721   911.340483         3.854638
# std      21.182870   726.718974         1.985535
# min       1.000000    10.000000         0.800000
# 25%       5.600000   432.000000         2.400000
# 50%      10.300000   625.000000         3.500000
# 75%      15.200000  1778.000000         4.800000
# max     120.000000  3048.000000        19.300000

# %%
df["geometry"].unique()
# Out:
# array(['tube', 'annulus', 'plate'], dtype=object)

# %%
df_aux = df[df["geometry"] == "plate"]
df_aux[df_aux ["D_e [mm]"] != df_aux ["D_h [mm]"]]
# Out:
#             author geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# 1817    Kossolapov    plate            0.10                    0      -0.1392
# 1818    Kossolapov    plate            0.10                 1484      -0.1392
# 1819    Kossolapov    plate            0.10                 2078      -0.1392
# 1820    Kossolapov    plate            0.10                  310      -0.0929
# 1821    Kossolapov    plate            0.10                  912      -0.0929
# 1822    Kossolapov    plate            0.10                 1277      -0.0929
# 1823    Kossolapov    plate            0.10                  340      -0.0466
# 1824    Kossolapov    plate            0.10                  630      -0.0466
# 1825    Kossolapov    plate            0.10                  882      -0.0466
# 1826    Kossolapov    plate            0.10                  336      -0.0187
# 1827    Kossolapov    plate            0.10                  524      -0.0187
# 1828    Kossolapov    plate            0.10                  734      -0.0187
# 1829  Richenderfer    plate            0.10                 1000      -0.0093
# 1830  Richenderfer    plate            0.10                 1000      -0.0187
# 1831  Richenderfer    plate            0.10                 1000      -0.0373
# 1832  Richenderfer    plate            0.10                 1500      -0.0093
# 1833  Richenderfer    plate            0.10                 1500      -0.0187
# 1834  Richenderfer    plate            0.10                 1500      -0.0373
# 1835  Richenderfer    plate            0.10                 2000      -0.0093
# 1836  Richenderfer    plate            0.10                 2000      -0.0187
# 1837  Richenderfer    plate            0.10                 2000      -0.0373
# 1838  Richenderfer    plate            0.20                 1000      -0.0096
# 1839  Richenderfer    plate            0.20                 1000      -0.0193
# 1840  Richenderfer    plate            0.20                 1000      -0.0385
# 1841  Richenderfer    plate            0.20                 1500      -0.0096
# 1842  Richenderfer    plate            0.20                 1500      -0.0193
# 1843  Richenderfer    plate            0.20                 1500      -0.0385
# 1844  Richenderfer    plate            0.20                 2000      -0.0096
