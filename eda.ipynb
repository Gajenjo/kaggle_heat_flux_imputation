# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data.csv")
df = df.copy()

# %%
df.drop(columns=["id", "author"], inplace=True)

# %%
df.shape
# Out:
# (31644, 8)

# %%
df.dropna(inplace=True)

# %%
df_unequal_diameter = df[df["D_e [mm]"]!=df["D_h [mm]"]]
df_unequal_diameter
# Out:
#       geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  D_e [mm]  \
# 3      annulus           13.79               3679.0      -0.0279       5.6
# 30     annulus            9.68               5615.0       0.0196      12.7
# 67     annulus            6.89               5588.0      -0.0157       6.4
# 108      plate            0.10               2000.0      -0.0093      15.0
# 125    annulus            6.92                555.0       0.1234      12.7
# ...        ...             ...                  ...          ...       ...
# 31554  annulus           13.79               2729.0       0.0863       5.6
# 31580  annulus            6.89               1519.0       0.1671       8.5
# 31584  annulus            6.91               2780.0       0.1200      12.7
# 31608  annulus           11.03               2729.0       0.0409       5.6
# 31623  annulus            8.27               2731.0       0.1601       5.0
#
#        D_h [mm]  length [mm]  chf_exp [MW/m2]
# ...

# %%
df_unequal_diameter[df_unequal_diameter["geometry"]=="plate"]
# Out:
#       geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  D_e [mm]  \
# 108      plate            0.10               2000.0      -0.0093      15.0
# 176      plate            0.20               2000.0      -0.0373      15.0
# 592      plate            0.20               1000.0      -0.0218      15.0
# 799      plate            0.10               5500.0      -0.0102      15.0
# 1115     plate            0.10               2078.0      -0.0373      15.0
# ...        ...             ...                  ...          ...       ...
# 30742    plate            1.01               2000.0      -0.1224      15.0
# 30823    plate            0.10               2000.0      -0.0665      15.0
# 30858    plate            0.20               1000.0      -0.1093      15.0
# 30870    plate            0.20               2000.0      -0.0345      15.0
# 31245    plate            1.01               2000.0      -0.0373      15.0
#
#        D_h [mm]  length [mm]  chf_exp [MW/m2]
# ...

# %%
df_unequal_diameter[df_unequal_diameter["geometry"]=="tube"]
# Out:
#       geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  D_e [mm]  \
# 375       tube            2.14               1500.0      -0.0466      15.0
# 809       tube           15.51               2710.0       0.1431       5.6
# 1866      tube            0.51               1000.0      -0.0102      15.0
# 3170      tube            1.01               2000.0      -0.0407      15.0
# 5153      tube           13.79               1354.0       0.0749       5.6
# 6024      tube            0.20               2000.0      -0.0373      15.0
# 8049      tube           13.79               1345.0       0.1274       5.6
# 9311      tube           15.51               3716.0       0.0716      15.2
# 9673      tube           13.79               3662.0       0.1219      15.0
# 9911      tube            0.10               1500.0      -0.0187      15.0
# 10383     tube           13.79               1355.0       0.1622       5.6
# ...

# %%
df_unequal_diameter[df_unequal_diameter["geometry"]=="annulus"]
# Out:
#       geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  D_e [mm]  \
# 3      annulus           13.79               3679.0      -0.0279       5.6
# 30     annulus            9.68               5615.0       0.0196      12.7
# 67     annulus            6.89               5588.0      -0.0157       6.4
# 125    annulus            6.92                555.0       0.1234      12.7
# 141    annulus            6.89                549.0       0.0497      12.7
# ...        ...             ...                  ...          ...       ...
# 31554  annulus           13.79               2729.0       0.0863       5.6
# 31580  annulus            6.89               1519.0       0.1671       8.5
# 31584  annulus            6.91               2780.0       0.1200      12.7
# 31608  annulus           11.03               2729.0       0.0409       5.6
# 31623  annulus            8.27               2731.0       0.1601       5.0
#
#        D_h [mm]  length [mm]  chf_exp [MW/m2]
# ...

# %%
df_equal_diameter = df[df["D_e [mm]"]==df["D_h [mm]"]]
df_equal_diameter[df_equal_diameter["geometry"]=="tube"]
# Out:
#       geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  D_e [mm]  \
# 9         tube           12.00               1617.0       0.1228      10.0
# 15        tube           12.07               3255.0       0.0406       1.9
# 17        tube           10.41               2563.0       0.1092       4.6
# 28        tube           13.79               2061.0      -0.0276       7.8
# 31        tube           12.00               1408.0       0.1103      10.0
# ...        ...             ...                  ...          ...       ...
# 31624     tube           13.79                963.0       0.1693       7.7
# 31626     tube           15.51               2984.0       0.0253       1.9
# 31627     tube            0.64               3282.0      -0.1224       3.0
# 31635     tube           17.24               2984.0      -0.0417       1.9
# 31643     tube            6.89               7568.0       0.0603      12.8
#
#        D_h [mm]  length [mm]  chf_exp [MW/m2]
# ...
